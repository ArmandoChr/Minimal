# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly_express==0.4.0
# Out:
# Requirement already satisfied: plotly_express==0.4.0 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (0.4.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas>=0.20.0 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from plotly_express==0.4.0) (2.1.1)
# Requirement already satisfied: plotly>=4.0.0 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from plotly_express==0.4.0) (5.17.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from plotly_express==0.4.0) (0.14.0)
# Requirement already satisfied: scipy>=0.18 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from plotly_express==0.4.0) (1.11.3)
# Requirement already satisfied: patsy>=0.5 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from plotly_express==0.4.0) (0.5.3)
# Requirement already satisfied: numpy>=1.11 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from plotly_express==0.4.0) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.20.0->plotly_express==0.4.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.20.0->plotly_express==0.4.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.20.0->plotly_express==0.4.0) (2023.3)
# Requirement already satisfied: six in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from patsy>=0.5->plotly_express==0.4.0) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from plotly>=4.0.0->plotly_express==0.4.0) (8.2.3)
# Requirement already satisfied: packaging in c:\users\arman\appdata\local\programs\python\python311\lib\site-packages (from plotly>=4.0.0->plotly_express==0.4.0) (23.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv(r"C:\Users\arman\Downloads\Python stuff\Jupyter\Project 2\survey_results_public.csv", low_memory=False)

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
# 4  Hobby;Contribute to open-source projects;Profe...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Colleague;Friend or family member;Other online...
# 4  Books / Physical media;Online Courses or Certi...
#
#                                      LearnCodeOnline  ...        Frequency_1  \
# 0                                                NaN  ...                NaN
# 1  Formal documentation provided by the owner of ...  ...   1-2 times a week
# 2  Formal documentation provided by the owner of ...  ...  6-10 times a week
# 3  Formal documentation provided by the owner of ...  ...   1-2 times a week
# 4  Formal documentation provided by the owner of ...  ...   1-2 times a week
#
#          Frequency_2       Frequency_3         TimeSearching  \
# 0                NaN               NaN                   NaN
# 1   10+ times a week             Never   15-30 minutes a day
# 2  6-10 times a week  3-5 times a week   30-60 minutes a day
# 3   10+ times a week  1-2 times a week   15-30 minutes a day
# 4   1-2 times a week  3-5 times a week  60-120 minutes a day
#
#          TimeAnswering                                   ProfessionalTech  \
# 0                  NaN                                                NaN
# 1  15-30 minutes a day  DevOps function;Microservices;Automated testin...
# 2  30-60 minutes a day  DevOps function;Microservices;Automated testin...
# 3  30-60 minutes a day  Automated testing;Continuous integration (CI) ...
# 4  30-60 minutes a day  Microservices;Automated testing;Observability ...
#
#                                             Industry           SurveyLength  \
# 0                                                NaN                    NaN
# 1  Information Services, IT, Software Development...  Appropriate in length
# 2  Information Services, IT, Software Development...  Appropriate in length
# 3                                                NaN  Appropriate in length
# 4                                              Other  Appropriate in length
#
#                    SurveyEase ConvertedCompYearly
# 0                         NaN                 NaN
# 1                        Easy            285000.0
# 2                        Easy            250000.0
# 3                        Easy            156000.0
# 4  Neither easy nor difficult             23456.0
#
# [5 rows x 84 columns]

# %%
print(f'Rows:{df.shape[0]}, Columns: {df.shape[1]}')
# Out:
# Rows:89184, Columns: 84

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
#        'AISearchWantToWorkWith', 'AIDevHaveWorkedWith', 'AIDevWantToWorkWith',
#        'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm',
#        'SOAI', 'AISelect', 'AISent', 'AIAcc', 'AIBen',
#        'AIToolInterested in Using', 'AIToolCurrently Using',
#        'AIToolNot interested in Using', 'AINextVery different',
#        'AINextNeither different nor similar', 'AINextSomewhat similar',
#        'AINextVery similar', 'AINextSomewhat different', 'TBranch', 'ICorPM',
#        'WorkExp', 'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Knowledge_8',
#        'Frequency_1', 'Frequency_2', 'Frequency_3', 'TimeSearching',
#        'TimeAnswering', 'ProfessionalTech', 'Industry', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
#
#             Employment RemoteWork  \
# 0                  NaN        NaN
# 1  Employed, full-time     Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
#
#                                      LearnCodeOnline  ...       Frequency_1  \
# 0                                                NaN  ...               NaN
# 1  Formal documentation provided by the owner of ...  ...  1-2 times a week
#
#         Frequency_2 Frequency_3        TimeSearching        TimeAnswering  \
# 0               NaN         NaN                  NaN                  NaN
# 1  10+ times a week       Never  15-30 minutes a day  15-30 minutes a day
#
#                                     ProfessionalTech  \
# 0                                                NaN
# 1  DevOps function;Microservices;Automated testin...
#
#                                             Industry           SurveyLength  \
# 0                                                NaN                    NaN
# 1  Information Services, IT, Software Development...  Appropriate in length
#
#   SurveyEase ConvertedCompYearly
# 0        NaN                 NaN
# 1       Easy            285000.0
#
# [2 rows x 84 columns]

# %%
df=df[['ResponseId','MainBranch','Age','Employment','RemoteWork','CodingActivities', 'EdLevel','YearsCode','DevType','Country','CompTotal','LanguageHaveWorkedWith',
       'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith','DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
       'PlatformWantToWorkWith', 'WebframeHaveWorkedWith','WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
       'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith','ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith','OpSysPersonal use','OpSysProfessional use','ConvertedCompYearly','WorkExp']]

# %%
df.shape
# Out:
# (89184, 28)

# %%
df.dropna(how="all")
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1                   None of these     18-24 years old
# 1               2  I am a developer by profession     25-34 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4  I am a developer by profession     25-34 years old
# 4               5  I am a developer by profession     25-34 years old
# ...           ...                             ...                 ...
# 89179       89180  I am a developer by profession     25-34 years old
# 89180       89181  I am a developer by profession     18-24 years old
# 89181       89182     I code primarily as a hobby   Prefer not to say
# 89182       89183  I am a developer by profession  Under 18 years old
# 89183       89184  I am a developer by profession     35-44 years old
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4      Employed, full-time;Independent contractor, fr...
# ...                                                  ...
# 89179  Employed, full-time;Independent contractor, fr...
# 89180             Student, full-time;Employed, part-time
# 89181                                I prefer not to say
# 89182             Employed, part-time;Student, part-time
# 89183                                Employed, full-time
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                                    Remote
# 2      Hybrid (some remote, some in-person)
# 3      Hybrid (some remote, some in-person)
# 4                                    Remote
# ...                                     ...
# 89179                                Remote
# 89180  Hybrid (some remote, some in-person)
# 89181                                   NaN
# 89182  Hybrid (some remote, some in-person)
# 89183  Hybrid (some remote, some in-person)
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1      Hobby;Contribute to open-source projects;Boots...
# 2      Hobby;Professional development or self-paced l...
# 3                                                  Hobby
# 4      Hobby;Contribute to open-source projects;Profe...
# ...                                                  ...
# 89179  Hobby;Bootstrapping a business;Freelance/contr...
# 89180                            School or academic work
# 89181                                                NaN
# 89182                      Hobby;School or academic work
# 89183  Hobby;Professional development or self-paced l...
#
#                                                  EdLevel YearsCode  \
# 0                                                    NaN       NaN
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)        18
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)        27
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)        12
# 4           Bachelor’s degree (B.A., B.S., B.Eng., etc.)         6
# ...                                                  ...       ...
# 89179                Associate degree (A.A., A.S., etc.)        20
# 89180       Bachelor’s degree (B.A., B.S., B.Eng., etc.)         5
# 89181                                     Something else        10
# 89182  Secondary school (e.g. American high school, G...         3
# 89183       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        17
#
#                                     DevType                       Country  \
# 0                                       NaN                           NaN
# 1      Senior Executive (C-Suite, VP, etc.)      United States of America
# 2                       Developer, back-end      United States of America
# 3                      Developer, front-end      United States of America
# 4                     Developer, full-stack                   Philippines
# ...                                     ...                           ...
# 89179                  Developer, front-end                        Brazil
# 89180                   Developer, back-end                       Romania
# 89181                                   NaN                        Israel
# 89182                  System administrator                   Switzerland
# 89183                 Developer, full-stack  Iran, Islamic Republic of...
#
#        ...                             WebframeWantToWorkWith  \
# 0      ...                                                NaN
# 1      ...               Deno;Elm;Nuxt.js;React;Svelte;Vue.js
# 2      ...                                                NaN
# 3      ...                       Node.js;Ruby on Rails;Vue.js
# 4      ...  Express;NestJS;Next.js;Node.js;React;Remix;Vue.js
# ...    ...                                                ...
# 89179  ...              Express;Node.js;Nuxt.js;Svelte;Vue.js
# 89180  ...                                        Spring Boot
# 89181  ...                                                NaN
# 89182  ...  Angular;AngularJS;Express;Next.js;Node.js;Reac...
# 89183  ...  Angular;ASP.NET;ASP.NET CORE;Blazor;Deno;Node....
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                            Electron;React Native;Tauri
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 89179                                            Flutter
# 89180  Flutter;Opencv;RabbitMQ;Spring Framework;Torch...
# 89181                            NumPy;Pandas;TensorFlow
# 89182                           CUDA;NumPy;Torch/PyTorch
# 89183              .NET (5+) ;.NET Framework (1.0 - 4.8)
#
#                               MiscTechWantToWorkWith  \
# 0                                                NaN
# 1      Capacitor;Electron;Tauri;Uno Platform;Xamarin
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 89179                                            NaN
# 89180        RabbitMQ;Spring Framework;Torch/PyTorch
# 89181                     NumPy;Pandas;Torch/PyTorch
# 89182    CUDA;Flutter;NumPy;TensorFlow;Torch/PyTorch
# 89183         .NET (5+) ;Apache Kafka;RabbitMQ;Tauri
#
#                                  ToolsTechHaveWorkedWith  \
# 0                                                    NaN
# 1            Docker;Kubernetes;npm;Pip;Vite;Webpack;Yarn
# 2                       Cargo;Docker;Kubernetes;Make;Nix
# 3                         Homebrew;npm;Vite;Webpack;Yarn
# 4                                Docker;npm;Webpack;Yarn
# ...                                                  ...
# 89179  Chocolatey;CMake;Docker;Maven (build tool);npm...
# 89180                             Maven (build tool);Pip
# 89181                                              Cargo
# 89182                  Docker;Kubernetes;npm;Podman;Vite
# 89183            Docker;npm;NuGet;pnpm;Vite;Webpack;Yarn
#
#                                  ToolsTechWantToWorkWith  \
# 0                                                    NaN
# 1      Godot;npm;pnpm;Unity 3D;Unreal Engine;Vite;Web...
# 2                                   Cargo;Kubernetes;Nix
# 3                                      Homebrew;npm;Vite
# 4                                        Docker;npm;Yarn
# ...                                                  ...
# 89179                           Docker;npm;Pip;Vite;Yarn
# 89180                             Maven (build tool);Pip
# 89181                  Cargo;Docker;Kubernetes;Terraform
# 89182  Ansible;APT;Docker;Kubernetes;npm;Pip;Podman;T...
# 89183                Bun;Docker;npm;NuGet;pnpm;Vite;Yarn
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                 Vim;Visual Studio Code
# 2                                            Emacs;Helix
# 3          IntelliJ IDEA;Vim;Visual Studio Code;WebStorm
# 4                                 Vim;Visual Studio Code
# ...                                                  ...
# 89179  Android Studio;Atom;Eclipse;IntelliJ IDEA;Netb...
# 89180               Android Studio;IntelliJ IDEA;PyCharm
# 89181  Jupyter Notebook/JupyterLab;Neovim;Visual Stud...
# 89182  Eclipse;IntelliJ IDEA;Nano;Notepad++;PyCharm;V...
# 89183                   Visual Studio;Visual Studio Code
#
#                                        OpSysPersonal use  \
# 0                                                    NaN
# 1      iOS;iPadOS;MacOS;Windows;Windows Subsystem for...
# 2                                MacOS;Other Linux-based
# 3                                       iOS;iPadOS;MacOS
# 4                                Other (Please Specify):
# ...                                                  ...
# 89179                                    Android;Windows
# 89180                                            Windows
# 89181                                            Windows
# 89182  Arch;Debian;iOS;iPadOS;MacOS;Ubuntu;Windows;Wi...
# 89183                                            Windows
#
#                                  OpSysProfessional use ConvertedCompYearly  \
# 0                                                  NaN                 NaN
# 1      MacOS;Windows;Windows Subsystem for Linux (WSL)            285000.0
# 2                              MacOS;Other Linux-based            250000.0
# 3                                     iOS;iPadOS;MacOS            156000.0
# 4                              Other (Please Specify):             23456.0
# ...                                                ...                 ...
# 89179                           Android;Ubuntu;Windows                 NaN
# 89180                                          Windows                 NaN
# 89181                                              NaN                 NaN
# 89182               BSD;Red Hat;Solaris;Ubuntu;Windows                 NaN
# 89183                                          Windows                 NaN
#
#       WorkExp
# 0         NaN
# 1        10.0
# 2        23.0
# 3         7.0
# 4         6.0
# ...       ...
# 89179     NaN
# 89180     NaN
# 89181     NaN
# 89182     NaN
# 89183    14.0
#
# [89184 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    89184 non-null  int64
#  1   MainBranch                    89184 non-null  object
#  2   Age                           89184 non-null  object
#  3   Employment                    87898 non-null  object
#  4   RemoteWork                    73810 non-null  object
#  5   CodingActivities              73764 non-null  object
#  6   EdLevel                       87973 non-null  object
#  7   YearsCode                     87435 non-null  object
#  8   DevType                       76872 non-null  object
#  9   Country                       87973 non-null  object
#  10  CompTotal                     48225 non-null  float64
#  11  LanguageHaveWorkedWith        87140 non-null  object
#  12  LanguageWantToWorkWith        80709 non-null  object
#  13  DatabaseHaveWorkedWith        73435 non-null  object
#  14  DatabaseWantToWorkWith        60911 non-null  object
#  15  PlatformHaveWorkedWith        63628 non-null  object
#  16  PlatformWantToWorkWith        51308 non-null  object
#  17  WebframeHaveWorkedWith        66938 non-null  object
#  18  WebframeWantToWorkWith        56741 non-null  object
#  19  MiscTechHaveWorkedWith        57019 non-null  object
#  20  MiscTechWantToWorkWith        46848 non-null  object
#  21  ToolsTechHaveWorkedWith       77884 non-null  object
#  22  ToolsTechWantToWorkWith       68315 non-null  object
#  23  NEWCollabToolsHaveWorkedWith  85864 non-null  object
#  24  OpSysPersonal use             86557 non-null  object
#  25  OpSysProfessional use         78587 non-null  object
#  26  ConvertedCompYearly           48019 non-null  float64
#  27  WorkExp                       43579 non-null  float64
# dtypes: float64(3), int64(1), object(24)
# memory usage: 19.1+ MB

# %%
# Age distribution

# %%
import plotly.io as pio

# %%
pio.renderers.default = 'iframe'

# %%
age_data = df['Age'].value_counts(sort=False)
fig = px.bar(data_frame=age_data, x=age_data.index, y=age_data.values, labels={'y': 'No. Respondents'},
             color=age_data.values, color_continuous_scale = 'tealrose')


fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_367.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#Dist. by country

# %%
top10_country = df['Country'].value_counts(sort=True).head(10)

top10_country = top10_country.rename({
    'United States of America': 'USA',
    'United Kingdom of Great Britain and Northern Ireland' : 'Britain'
})
top10_country
# Out:
# Country
# USA            18647
# Germany         7328
# India           5625
# Britain         5552
# Canada          3507
# France          2933
# Poland          2435
# Netherlands     2383
# Australia       2078
# Brazil          2042
# Name: count, dtype: int64

# %%
fig = px.histogram(data_frame=top10_country, x=top10_country.index, y=top10_country.values,
                   labels={'y' : 'No. of Respondents'})
fig.update_traces(marker_color = 'teal')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_370.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df['YearsCode'].head()
# Out:
# 0    NaN
# 1     18
# 2     27
# 3     12
# 4      6
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].value_counts()
# Out:
# YearsCode
# 10                    6521
# 5                     5415
# 6                     4893
# 8                     4879
# 7                     4800
# 4                     4466
# 15                    4336
# 3                     4269
# 20                    4021
# 12                    3471
# 9                     3130
# 2                     2826
# 25                    2685
# 13                    2601
# 11                    2519
# 14                    2278
# 30                    2078
# 16                    1842
# 18                    1690
# 17                    1544
# 23                    1327
# 40                    1302
# 1                     1294
# 22                    1210
# 35                    1118
# Less than 1 year       968
# 24                     959
# 19                     826
# 21                     761
# 28                     715
# 27                     710
# 26                     706
# 33                     496
# 32                     444
# 38                     428
# 45                     360
# More than 50 years     353
# 42                     347
# 34                     333
# 29                     324
# 37                     312
# 36                     282
# 31                     272
# 43                     265
# 39                     229
# 41                     227
# 44                     160
# 50                     125
# 46                     101
# 48                      96
# 47                      79
# 49                      42
# Name: count, dtype: int64

# %%
years_data = df['YearsCode'].value_counts(ascending=False)
print(df.shape)
# Out:
# (89184, 28)

# %%
fig = px.bar(data_frame=years_data, x=years_data.index, y=years_data.values, color=years_data.values, color_continuous_scale='tealrose',
             labels={'y':'Number of Respondents'}, title='Respondents by Year')

fig.update_layout(
    font=dict(size=16, family='Times New Roman'),
    bargap=0.2,
    plot_bgcolor='white',
    paper_bgcolor='white',
    height=700
)

fig.update_traces(
    hovertemplate='Year: %{x}<br>: %{y}',
)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="720"
#     src="iframe_figures/figure_374.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
#Devtype string conv.

# %%
profession_count = dict()
for professions in df['DevType']:
    try:
        professions = professions.replace(';', ',')
        profession = professions.split(',')
        for x in profession:
            profession_count[x] = profession_count.get(x, 0) + 1
    except:
        continue

profession_count = dict(sorted(profession_count.items(), key=lambda x: x[1], reverse=True)[1:19])
profession_count = dict(sorted(profession_count.items(), key=lambda x: x[1]))

# %%
print(profession_count)
# Out:
# {' data': 1248, 'Senior Executive (C-Suite': 1332, ' VP': 1332, ' etc.)': 1332, 'Research & Development role': 1353, 'Academic researcher': 1354, 'DevOps specialist': 1387, 'Data scientist or machine learning specialist': 1588, 'Engineer': 1675, ' embedded applications or devices': 1845, 'Student': 1996, 'Engineering manager': 2033, ' mobile': 2597, 'Other (please specify):': 3080, ' desktop or enterprise applications': 3904, ' front-end': 5071, ' back-end': 13745, ' full-stack': 25735}

# %%
#chose to remove the option as it is a strange aletrnative to include in a survey on its own.
profession_count.pop(' etc.)')
# Out:
# 1332

# %%
from matplotlib import style

# %%
#make horizontal to fit better

# %%
profession_count = pd.Series(profession_count)
plt.figure(figsize=(12,8))
plt.barh(profession_count.index, profession_count.values)
plt.xlabel('Number of Respondents', fontdict={'weight':'bold'})
plt.style.use('ggplot')
plt.show()

# %%
Lang_count=dict()
for languages in df['LanguageHaveWorkedWith']:
    try:
        lang=languages.split(';')
        for x in lang:
            Lang_count[x] = Lang_count.get(x,0)+1
    except:
        continue


Lang_count=dict(sorted(Lang_count.items(), key=lambda x: x[1], reverse=True)[:15])
Lang_count=dict(sorted(Lang_count.items(), key=lambda x:x[1]))

# %%
Lang_count = pd.Series(Lang_count)

plt.figure(figsize=(20,10))
plt.barh(Lang_count.index, Lang_count.values)
plt.xlabel('Number of Respondents', fontdict={'weight':'bold'})
plt.style.use('ggplot')
plt.show()

# %%
#Check corr between workexp and yearly compensation!
